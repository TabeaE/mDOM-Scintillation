# %%
from __future__ import division
#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#from scipy.interpolate import interp1d
# Out:
# /home/classenl/.virtualenvs/km3net/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# !ls checking_cherenkov_spectrum
# Out:
# ch_spectr_vitrovex_air.txt  ch_spectr_vitrovex_spice.txt

# %%
folder = "./checking_cherenkov_spectrum/" 
filename = "ch_spectr_vitrovex_spice.txt"

# %% [markdown]
# ## K40 checks:
# - orignal Cherenkov spectrum

# %%
# sns.set_style("whitegrid")
sns.set_style("darkgrid")
sns.set_context("talk")
sns.set_palette("deep")

# %%
wavelengths = np.loadtxt(folder+"ch_spectr_vitrovex_spice.txt", unpack=True)
print len(wavelengths)
wavelengths2 = np.loadtxt(folder+"ch_spectr_vitrovex_air.txt", unpack=True)
print len(wavelengths2)
# Out:
# 59097
# 41789

# %%
cols = sns.color_palette("deep", 10)
fig = plt.figure(figsize=(10,8))
ax = fig.gca()

binwidth = 10

plt.hist(wavelengths, bins=range(100, 800 + binwidth, binwidth), label="orig spectr spice")
plt.hist(wavelengths2, bins=range(100, 800 + binwidth, binwidth), label="orig spectr air")


ax.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("Cherenkov photon wavelength [nm]", fontsize=18)
plt.ylabel("hits", fontsize=18)
plt.grid(True)
#plt.xlim(0, 180)
#plt.ylim(0, 1.1)
plt.legend(loc="best", fontsize=15)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig = plt.figure(figsize=(15,12))
ax = fig.gca()

binwidth = 10
plt.hist(1240/energy_eV, bins=range(100, 800 + binwidth, binwidth), label="spectrum @ PMTs, mDOM")

ax.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("wavelength [nm]", fontsize=18)
plt.ylabel("hits", fontsize=18)
plt.grid(True)
plt.xlim(100, 800)
#plt.ylim(0, 1.1)
plt.legend(loc="best", fontsize=15)
# Out:
# <img src="data:image/png;base64,...">

# %%
# event#  hit time/ns  flight time/ns  track length/m  energy/eV PMT#  event distance/m  photon position[m] x,y,z  direction x,y,z distance[m]

#num_event, track_length, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("test_scan_normalDOM_t0_individual.txt", usecols=(0,3,5,6,7,8,9), unpack=True)
num_event, track_length, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("test_scan_normalDOM_t0_individual.txt", usecols=(0,3,5,6,7,8,9), unpack=True)

# %%
print "Total hits", len(num_event)

nums = [0, 1, 2, 3]
for num in nums:
    print "Hits on PMT #", num, len(num_event[num_pmt==num])

fig = plt.figure(figsize=(15,12))
ax = fig.gca()

condition = [num_pmt==0]
#condition = [(num_pmt==0) | (num_pmt==1)]
#condition = [(num_pmt>=0) & (num_pmt<=4)]

# #norm=LogNorm()
plt.hist2d(hit_x[condition], hit_y[condition], bins=200)
#plt.hist2d(hit_x[condition], hit_z[condition], bins=100)
plt.colorbar()
# Out:
# Total hits 2949275
# Hits on PMT # 0 419966
# Hits on PMT # 1 431590
# Hits on PMT # 2 420425
# Hits on PMT # 3 432222
# <img src="data:image/png;base64,...">

# %%
np.hs
