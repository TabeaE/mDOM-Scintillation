# %%
from __future__ import division
#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#from scipy.interpolate import interp1d

# %%
# !ls
# Out:
# for_Chris		mdom_testoutput_K40.txt
# K40_distribution.ipynb	mdom_testoutput_scan_angular.txt
# mdom_k40_data_1e5.txt	mdom_testoutput_scan_xyz.txt
# mdom_k40_data_1e6.txt	t180_0_bug

# %% [markdown]
# ## K40 hit properties

# %%
# 789 = xyz
# event#  hit time/ns  flight time/ns  track length/m  energy/eV PMT#  event distance/m  photon position[m] x,y,z  direction x,y,z distance[m]
#num_event, track_length, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("test_scan_normalDOM_corr_t0_individual_n10000000.txt", usecols=(0,3,5,6,7,8,9), unpack=True)
num_event, track_length, energy_eV, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("mdom_k40_data_1e6.txt", usecols=(0,3,4,5,6,7,8,9), unpack=True)

# %%
sns.set_palette("deep")
print "Total hits", len(num_event)

nums = [0, 1, 2, 3]
for num in nums:
    print "Hits on PMT #", num, len(num_event[num_pmt==num])

fig = plt.figure(figsize=(15,12))
ax = fig.gca()

#condition = [num_pmt==0]
#condition = [(num_pmt==0) | (num_pmt==1)]
condition = [(num_pmt>=12) & (num_pmt<=23)]

# #norm=LogNorm()
plt.hist2d(hit_x[condition], hit_y[condition], bins=400)
plt.colorbar()


# plt.legend(loc="best", fontsize=15)
# plt.xlim(-1, 181)
# plt.grid(True)

# ax.set_xlabel("theta", fontsize=20)
# ax.set_ylabel("detected/emitted", fontsize=20)
# ax.tick_params(axis='both', which='major', labelsize=15)
# Out:
# Total hits 4166540
# Hits on PMT # 0 163067
# Hits on PMT # 1 162382
# Hits on PMT # 2 161766
# Hits on PMT # 3 159578
# <img src="data:image/png;base64,...">

# %%
nums = range(24)
for num in nums:
    print "Hits on PMT #", num, len(num_event[num_pmt==num])
# Out:
# Hits on PMT # 0 163067
# Hits on PMT # 1 162382
# Hits on PMT # 2 161766
# Hits on PMT # 3 159578
# Hits on PMT # 4 179919
# Hits on PMT # 5 180749
# Hits on PMT # 6 181096
# Hits on PMT # 7 180408
# Hits on PMT # 8 180304
# Hits on PMT # 9 180338
# Hits on PMT # 10 183022
# Hits on PMT # 11 178991
# Hits on PMT # 12 171287
# Hits on PMT # 13 184215
# Hits on PMT # 14 175443
# Hits on PMT # 15 184162
# Hits on PMT # 16 175579
# Hits on PMT # 17 180842
# Hits on PMT # 18 175075
# Hits on PMT # 19 180543
# Hits on PMT # 20 163227
# Hits on PMT # 21 160032
# Hits on PMT # 22 162831
# Hits on PMT # 23 161684

# %%
# sns.set_style("whitegrid")
sns.set_style("darkgrid")
sns.set_context("talk")

# %%
cols = sns.color_palette("deep", 10)
fig = plt.figure(figsize=(10,8))
ax = fig.gca()

plt.hist(energy_eV, bins=50, label="spectrum @ PMTs, KM3NeT")

ax.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("photon energy [eV]", fontsize=18)
plt.ylabel("hits", fontsize=18)
plt.grid(True)
#plt.xlim(0, 180)
#plt.ylim(0, 1.1)
plt.legend(loc="best", fontsize=15)
# Out:
# <img src="data:image/png;base64,...">

# %%
fig = plt.figure(figsize=(15,12))
ax = fig.gca()

binwidth = 10
plt.hist(1240/energy_eV, bins=range(100, 800 + binwidth, binwidth), label="spectrum @ PMTs, mDOM", color="orange")

ax.tick_params(axis='both', which='major', labelsize=15)
plt.xlabel("wavelength [nm]", fontsize=18)
plt.ylabel("hits", fontsize=18)
plt.grid(True)
plt.xlim(100, 800)
#plt.ylim(0, 1.1)
plt.legend(loc="best", fontsize=15)
# Out:
# <img src="data:image/png;base64,...">

# %%
# event#  hit time/ns  flight time/ns  track length/m  energy/eV PMT#  event distance/m  photon position[m] x,y,z  direction x,y,z distance[m]

#num_event, track_length, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("test_scan_normalDOM_t0_individual.txt", usecols=(0,3,5,6,7,8,9), unpack=True)
num_event, track_length, num_pmt, event_dist, hit_x, hit_y, hit_z  = np.loadtxt("test_scan_normalDOM_t0_individual.txt", usecols=(0,3,5,6,7,8,9), unpack=True)

# %%
print "Total hits", len(num_event)

nums = [0, 1, 2, 3]
for num in nums:
    print "Hits on PMT #", num, len(num_event[num_pmt==num])

fig = plt.figure(figsize=(15,12))
ax = fig.gca()

condition = [num_pmt==0]
#condition = [(num_pmt==0) | (num_pmt==1)]
#condition = [(num_pmt>=0) & (num_pmt<=4)]

# #norm=LogNorm()
plt.hist2d(hit_x[condition], hit_y[condition], bins=200)
#plt.hist2d(hit_x[condition], hit_z[condition], bins=100)
plt.colorbar()
# Out:
# Total hits 2949275
# Hits on PMT # 0 419966
# Hits on PMT # 1 431590
# Hits on PMT # 2 420425
# Hits on PMT # 3 432222
# <img src="data:image/png;base64,...">
